# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import scanpy as scp
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.axes_grid.inset_locator import inset_axes
import matplotlib.patches as mpatches
import igraph
import scipy.stats as st
import bbknn
import os

from parameters import *

import sys
sys.path.append('../')
import single_cell_tools.tools as scttools
import single_cell_tools.plot as sctplot
# Out:
# 2022-08-22 13:26:03.761209: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-22 13:26:03.761227: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
adata_embryo = scp.read("../Data_other_studies/Bigas/Embryo_corrected.h5ad")
scp.pp.highly_variable_genes(adata_embryo)

# %%
adata_embryo.X = adata_embryo.obsm["X_raw"].copy()
adata_embryo.var["gene_id"] = adata_embryo.var.index.values

# %%
adata_gastruloid = scp.read(DIRECTORY+"Results/QC.h5ad")
adata_gastruloid.var["gene_id"] = adata_gastruloid.var.index.values

# %% [markdown]
# # Centroid

# %%
m = adata_gastruloid.obs.groupby("leiden",dropna=False).count()

# %%
fig,ax = plt.subplots(1,3,figsize=[55,15])

scttools.scmap_annotate(adata_gastruloid,adata_embryo,"gene_id","Louvain Cluster",key_added="Annotation",similarity_threshold=.7,algorithm_flavor="centroid",unassigned_label="100",verbose=False)
scttools.scmap_projection(adata_gastruloid,adata_embryo,"gene_id","X_umap_original",key_added="Annotation",verbose=False)

m = adata_gastruloid.obs.groupby("Annotation").count()
for i in adata_embryo.obs.groupby("Louvain Cluster",dropna=False).count().index:
    if str(i) not in m.index.values:
        m.loc[str(i),:] = .001
m.index = m.index.astype(int)
m.sort_index(inplace=True)
labels = [str(i)+":"+str(np.round(j,decimals=2)) for i,j in zip(m.index,m.iloc[:,0]/m.iloc[:,0].sum())]
labels[-1] = "NA:"+labels[-1][4:]
m.plot.pie(y="Cell",ax=ax[0],fontsize=0,labels=labels,colors=sns.color_palette("Paired"))
sctplot.plot_base(ax[0],title="Proportions of cells of gastruloid mapped to Embryo clusters",labels=["",""],legend_pos=(.92,0),legend_title="Embryo clusters")

order = np.argsort(adata_embryo.obs["Louvain Cluster"].astype(int)).values    
sns.scatterplot(adata_embryo.obsm["X_umap_original"][order,0],adata_embryo.obsm["X_umap_original"][order,1],hue=adata_embryo.obs["Louvain Cluster"].astype(str).iloc[order],ax=ax[1],s=100,palette="Paired")
only = adata_gastruloid.obs["Annotation"] == "100"
sns.scatterplot(adata_gastruloid.obsm["Annotation"][only,0],adata_gastruloid.obsm["Annotation"][only,1],ax=ax[1],color="grey",s=400)
only = adata_gastruloid.obs["Annotation"] != "100"
sns.scatterplot(adata_gastruloid.obsm["Annotation"][only,0],adata_gastruloid.obsm["Annotation"][only,1],ax=ax[1],color="black",s=400)
sctplot.plot_base(ax[1],title="Gastruloid cell projected over Embryo UMAP",labels=["UMAP dimension 1","UMAP dimension 2"],legend_pos=(0.01,.3),legend_title="Embryo clusters")

sns.scatterplot(adata_embryo.obsm["X_umap_original"][:,0],adata_embryo.obsm["X_umap_original"][:,1],color="grey",ax=ax[2],s=100,palette="Paired")
sns.scatterplot(adata_gastruloid.obsm["Annotation"][:,0],adata_gastruloid.obsm["Annotation"][:,1],hue=adata_gastruloid.obs["leiden"].values,ax=ax[2],s=400)
sctplot.plot_base(ax[2],title="Gastruloid cell projected over Embryo UMAP",labels=["UMAP dimension 1","UMAP dimension 2"],legend_pos=(0.01,.3),legend_title="Gastruloid clusters")

fig.savefig(DIRECTORY+"Plots/Proj_Bigas_datast_centroid_mapping.pdf",bbox_inches="tight",transparent=True)

# %% [markdown]
# # Cell

# %%
fig,ax = plt.subplots(1,3,figsize=[55,15])

scttools.scmap_annotate(adata_gastruloid,adata_embryo,"gene_id","Louvain Cluster",key_added="Annotation",similarity_threshold=.7,algorithm_flavor="cell",unassigned_label="100",verbose=False)
scttools.scmap_projection(adata_gastruloid,adata_embryo,"gene_id","X_umap_original",key_added="Annotation",verbose=False)

m = adata_gastruloid.obs.groupby("Annotation").count()
for i in adata_embryo.obs.groupby("Louvain Cluster",dropna=False).count().index:
    if str(i) not in m.index.values:
        m.loc[str(i),:] = .001
m.index = m.index.astype(int)
m.sort_index(inplace=True)
labels = [str(i)+":"+str(np.round(j,decimals=2)) for i,j in zip(m.index,m.iloc[:,0]/m.iloc[:,0].sum())]
labels[-1] = "NA:"+labels[-1][4:]
m.plot.pie(y="Cell",ax=ax[0],fontsize=0,labels=labels,colors=sns.color_palette("Paired"))
sctplot.plot_base(ax[0],title="Proportions of cells of gastruloid mapped to Embryo clusters",labels=["",""],legend_pos=(.92,0),legend_title="Embryo clusters")

order = np.argsort(adata_embryo.obs["Louvain Cluster"].astype(int)).values    
sns.scatterplot(adata_embryo.obsm["X_umap_original"][order,0],adata_embryo.obsm["X_umap_original"][order,1],hue=adata_embryo.obs["Louvain Cluster"].astype(str).iloc[order],ax=ax[1],s=100,palette="Paired")
only = adata_gastruloid.obs["Annotation"] == "100"
sns.scatterplot(adata_gastruloid.obsm["Annotation"][only,0],adata_gastruloid.obsm["Annotation"][only,1],ax=ax[1],color="grey",s=400)
only = adata_gastruloid.obs["Annotation"] != "100"
sns.scatterplot(adata_gastruloid.obsm["Annotation"][only,0],adata_gastruloid.obsm["Annotation"][only,1],ax=ax[1],color="black",s=400)
sctplot.plot_base(ax[1],title="Gastruloid cell projected over Embryo UMAP",labels=["UMAP dimension 1","UMAP dimension 2"],legend_pos=(0.01,.3),legend_title="Embryo clusters")

sns.scatterplot(adata_embryo.obsm["X_umap_original"][:,0],adata_embryo.obsm["X_umap_original"][:,1],color="grey",ax=ax[2],s=100,palette="Paired")
sns.scatterplot(adata_gastruloid.obsm["Annotation"][:,0],adata_gastruloid.obsm["Annotation"][:,1],hue=adata_gastruloid.obs["leiden"].values,ax=ax[2],s=400)
sctplot.plot_base(ax[2],title="Gastruloid cell projected over Embryo UMAP",labels=["UMAP dimension 1","UMAP dimension 2"],legend_pos=(0.01,.3),legend_title="Gastruloid clusters")

fig.savefig(DIRECTORY+"Plots/Proj_Bigas_datast_cell_mapping.pdf",bbox_inches="tight",transparent=True)

# %% [markdown]
# # DE genes from embryo expressed in gastruloid clusters

# %%
adata_embryo.obs["Louvain Cluster"] = adata_embryo.obs["Louvain Cluster"].astype(str)
scp.tl.rank_genes_groups(adata_embryo,groupby="Louvain Cluster",method="wilcoxon")
    
cut = 5

cluster_genes = {}
for i,group in enumerate(adata_embryo.obs["Louvain Cluster"].cat.categories.values):
    cluster_genes[group] = []
    for j in range(100):
        if adata_embryo.uns["rank_genes_groups"]["scores"][j][i] > cut and adata_embryo.uns["rank_genes_groups"]["names"][j][i] in adata_gastruloid.var["gene_id"].values:
            cluster_genes[group].append(adata_embryo.uns["rank_genes_groups"]["names"][j][i])
                
fig = scp.pl.heatmap(adata_gastruloid, cluster_genes, groupby="leiden", standard_scale="var", swap_axes=False, figsize=(20,10),show=False)
sctplot.plot_base(fig["heatmap_ax"],title="",labels=["Embryo DE genes by clusters",""],legend=False)
sctplot.plot_base(fig["groupby_ax"],title="",labels=["","Gastruloid cells by clusters"],legend=False)

plt.savefig(DIRECTORY+"Plots/Proj_Bigas_DE_projected.pdf",bbox_inches="tight",transparent=True)
# Out:
# ... storing 'Louvain Cluster' as categorical
# ... storing 'Annotation' as categorical
# WARNING: Gene labels are not shown when more than 50 genes are visualized. To show gene labels set `show_gene_labels=True`
