# %%
import pandas as pd
import scipy.io as io
import numpy as np
import scanpy as scp
import seaborn as sns
import matplotlib.pyplot as plt

from parameters import *

import sys
sys.path.append('../../')
import single_cell_tools.tools as scttools
import single_cell_tools.plot as sctplot

# %%
obs = pd.read_csv("Cell_annotation_final.txt", sep="\t").set_index("Library_name")
obs
# Out:
#                                                     Plate_well  \
# Library_name
# GL53_001_Plate3_a1_Gfi1_HE_S1                        Plate3_A1
# GL53_002_Plate3_b1_Gfi1_HE_S2                        Plate3_B1
# GL53_003_Plate3_c1_Gfi1_HE_S3                        Plate3_C1
# GL53_004_Plate3_d1_Gfi1_HE_S4                        Plate3_D1
# GL53_005_Plate3_e1_Gfi1_HE_S5                        Plate3_E1
# ...                                                        ...
# GL78_380_WN-S3-P5_C14_AGM_E11-5_SP_47-48_Gfi1_H...  Plate4_C14
# GL78_381_WN-S3-P5_A15_AGM_E11-5_SP_47-48_Gfi1_H...  Plate4_A15
# GL78_382_WN-S3-P5_C17_AGM_E11-5_SP_47-48_Gfi1_H...  Plate4_C17
# GL78_383_WN-S3-P5_C22_AGM_E11-5_SP_47-48_Gfi1_H...  Plate4_C22
# GL78_384_WN-S3-P5_D23_AGM_E11-5_SP_47-48_Gfi1_H...  Plate4_D23
#
#                                                    developmental_stage  \
# Library_name
# GL53_001_Plate3_a1_Gfi1_HE_S1                                    E11.5
# ...

# %%
X = pd.read_csv("Norm_counts_filtered.txt", sep="\t").transpose()
X
# Out:
#                                                        Gnai3     Cdc45  \
# GL53_001_Plate3_a1_Gfi1_HE_S1                       0.630765  1.004371
# GL53_003_Plate3_c1_Gfi1_HE_S3                       0.238051  1.424205
# GL53_004_Plate3_d1_Gfi1_HE_S4                       0.000000  0.000000
# GL53_006_Plate3_f1_Gfi1_HE_S6                       0.856998  0.000000
# GL53_007_Plate3_g1_Gfi1_pos_IAHC_S7                 0.470126  0.000000
# ...                                                      ...       ...
# GL78_380_WN-S3-P5_C14_AGM_E11-5_SP_47-48_Gfi1_H...  0.497722  0.000000
# GL78_381_WN-S3-P5_A15_AGM_E11-5_SP_47-48_Gfi1_H...  0.215234  0.805038
# GL78_382_WN-S3-P5_C17_AGM_E11-5_SP_47-48_Gfi1_H...  0.188482  0.000000
# GL78_383_WN-S3-P5_C22_AGM_E11-5_SP_47-48_Gfi1_H...  0.000000  1.389175
# GL78_384_WN-S3-P5_D23_AGM_E11-5_SP_47-48_Gfi1_H...  0.594268  0.000000
#
#                                                          H19     Scml2  Apoh  \
# ...

# %%
X_raw = pd.read_csv("Raw_counts_final.txt", sep="\t").transpose()
X_raw
# Out:
#                                                     ENSMUSG00000000001  \
# GL53_001_Plate3_a1_Gfi1_HE_S1                                       63
# GL53_002_Plate3_b1_Gfi1_HE_S2                                        0
# GL53_003_Plate3_c1_Gfi1_HE_S3                                       19
# GL53_004_Plate3_d1_Gfi1_HE_S4                                        0
# GL53_005_Plate3_e1_Gfi1_HE_S5                                       61
# ...                                                                ...
# GL78_380_WN-S3-P5_C14_AGM_E11-5_SP_47-48_Gfi1_H...                  52
# GL78_381_WN-S3-P5_A15_AGM_E11-5_SP_47-48_Gfi1_H...                  20
# GL78_382_WN-S3-P5_C17_AGM_E11-5_SP_47-48_Gfi1_H...                  24
# GL78_383_WN-S3-P5_C22_AGM_E11-5_SP_47-48_Gfi1_H...                   0
# GL78_384_WN-S3-P5_D23_AGM_E11-5_SP_47-48_Gfi1_H...                  66
#
#                                                     ENSMUSG00000000003  \
# ...

# %%
X_umap = obs.loc[X.index.values,["UMAP_C1","UMAP_C2"]].values

# %%
adata = scp.AnnData(X_raw.loc[X.index.values,:].values, obs=obs.loc[X.index.values,:], var = pd.DataFrame(X_raw.columns,columns=["ENS"]), obsm={"X_umap":X_umap})
adata.write("./Thambyrajah.h5ad")
# Out:
# ... storing 'Plate_well' as categorical
# ... storing 'developmental_stage' as categorical
# ... storing 'population' as categorical
# ... storing 'Batch_name' as categorical
# ... storing 'CellCycle' as categorical
